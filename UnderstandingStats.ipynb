# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from utils import *

# %%
process_subject('0eHy4fTr')
# Out:
# downs -> [ 93 176 284 364] from get_segments()
# ups -> [ 46 135 224 314 410] from get_segments()
# downs -> [ 19  93 176 284 364 454] from get_segments() after correction
# ups -> [ 46 135 224 314 410] from get_segments() after correction
# {'subjectid': '0eHy4fTr',
#  'orientation': 'R',
#  'framerate': 30.0,
#  'n': 5,
#  'time': 14.5,
#  'time_diff': 0.1333333333333333,
#  'speed': 0.34,
#  'time_sd': 0.3898717737923586,
#  'speed_sd': 0.043169056084899314,
#  'n_sit2stand': 5,
#  'time_sit2stand': 6.433333333333334,
#  'time_diff_sit2stand': -0.26666666666666666,
#  'speed_sit2stand': 0.78,
#  'time_sd_sit2stand': 0.28409701003550025,
#  'speed_sd_sit2stand': 0.19723613408315407,
#  'n_stand2sit': 4,
#  'time_stand2sit': 6.6000000000000005,
#  'time_diff_stand2sit': 0.425,
#  'speed_stand2sit': 0.61,
#  'time_sd_stand2sit': 0.22912878474779197,
#  'speed_sd_stand2sit': 0.08304872479485746,
#  'left_knee_range_mean': 92.87662205990408,
#  'left_knee_sd': 35.12323291546856,
# ...

# %%
data = np.load(r'E:\PhD Work (Local)\Sit to Stand Fall Risk Project (old)\np\0eHy4fTr.npy')
data.shape
# Out:
# (546, 75)

# %%
pd.DataFrame(data).to_csv(r'E:\PhD Work (Local)\Sit to Stand Fall Risk Project (old)\np\0eHy4fTr.csv', index=False)
